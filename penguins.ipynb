# %% [markdown]
# # Palmer Penguins
# ---
#
# This notebook contains my analysis of the famous palmer penguin dataset.

# %%
# Data frames (speadsheets).
import pandas as pd

# %%
# Load the penguin dataset
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/penguins.csv')

# %%
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    MALE
# 1         3800.0  FEMALE
# 2         3250.0  FEMALE
# 3            NaN     NaN
# 4         3450.0  FEMALE
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  FEMALE
# 341       5750.0    MALE
# 342       5200.0  FEMALE
# 343       5400.0    MALE
#
# [344 rows x 7 columns]

# %%
# Take a look at the first 10 variables from the data set
df.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE
# 5       3650.0    MALE
# 6       3625.0  FEMALE
# 7       4675.0    MALE
# 8       3475.0     NaN
# 9       4250.0     NaN

# %%
# Using indexes to look at specific rows - df.iloc, stands for index location.
df.iloc[0]
# Out:
# species                 Adelie
# island               Torgersen
# bill_length_mm            39.1
# bill_depth_mm             18.7
# flipper_length_mm        181.0
# body_mass_g             3750.0
# sex                       MALE
# Name: 0, dtype: object

# %%
# Count the number of penguins of each sex.
# Command requires empty round brackets at the end to run correctly.
df['sex'].value_counts()
# Out:
# sex
# MALE      168
# FEMALE    165
# Name: count, dtype: int64

# %%
# Count the number of penguins in each species
df['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
# Describe the data set.
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ## Variable Types
# ---

# %% [markdown]
# The variables I would use to model the variables in the data set are bar charts, histograms, scatter plots and distributions.

# %% [markdown]
# ### Bar Charts

# %% [markdown]
# A bar chart is a model that shows the counts of values for levels of categorical or nominal variables[^1]. The bars show the levels of the variables, while the height of the bars show the frequency counts for that level[^1]. Bar charts can be used to show the frequency of each penguin species across the three islands along with the frequency of each gender noted for the three species.
#
# [^1]: https://www.jmp.com/en_nl/statistics-knowledge-portal/exploratory-data-analysis/bar-chart.html.

# %% [markdown]
# ### Histograms

# %% [markdown]
# A histogram is a model that shows the distribution of a continuous variable[^2]. They help to see the center, spread and shape of a data set and can be used as a tool to check for normality[^2]. The x-axis contains the data values where is each bar includes a range of values and the y-axis shows how many points in the data have values in the specified ranges[^2]. Histograms can be used to look at each penguin species individually and see how variables such as flipper length and bill length differ across a species.
#
# [^2]: https://www.jmp.com/en_nl/statistics-knowledge-portal/exploratory-data-analysis/histogram.html.

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Unlike histograms and bar charts, scatter plots use dots to represent values for two different numeric variables[^3]. The position of each dot on the x and y axis indicates values for an individual data point[^3]. Scatter plots are primarily used to observe and show relationships between two numeric values[^3]. These relationships can be described as positive, negative, strong, weak, linear or nonlinear[^3]. Variables with a strong correlation have a value of r close to 1 or -1. 1 = a strong positive relationship, -1 = a strong negative relationship and 0 = no relationship. A scatter plot is an important model as it may show a relationship between variables in the Palmer set such as whether flipper size and body mass are related and what does this mean for each penguin species.
#
# [^3]: https://www.atlassian.com/data/charts/what-is-a-scatter-plot.

# %% [markdown]
# ### Distribution

# %% [markdown]
# A distribution in statistics is a function shows the possible values for a variable and how often they occur[^4]. The distribution types can be divided into continuous, e.g., normal distribution and t-distribution and discrete, e.g., Bernoulli and Poisson distributions[^5]. The most common of these types is normal distrubution also known as Gaussian distribution[^5]. A normal distribution is a symmetrical, bell-shaped curve, where most of the data is clustered around the center and tapers off at each end point[^5]. In this type of distribution, the mean, mode and median are all the same[^5]. Variables in the Palmer Penguin set such as body mass and bill length as likely the fit this curve and will give an insight into what the mean is for these variables.
#
# [^4]: https://365datascience.com/tutorials/statistics-tutorials/distribution-in-statistics/.
# [^5]: https://www.analytixlabs.co.in/blog/types-of-distribution/.

# %% [markdown]
# ## Bar Chart
# ---

# %% [markdown]
# In a study by Gorman et al[^6], which the data for the Palmer penguins is taken from, the author suggests that certain traits are greater predictors of gender than others. Examples of this are body mass and culmen (bill) length and depth[^6]. Below I will present a bar chart of the frequency of male and female penguins from each species.
#
# [^6]: https://doi.org/10.1371/journal.pone.0090081

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

# %%
# Group the number of each species by sex
# Number of each female species
female_df = (pd.DataFrame(df[df['sex'] == 'FEMALE'][['species', 'sex']].groupby('species')['sex'].count()).sort_values('sex', ascending=False).reset_index().rename(columns={'Sex': 'Female'}))
female_df
# Out:
#      species  sex
# 0     Adelie   73
# 1     Gentoo   58
# 2  Chinstrap   34

# %%
# Number of each male species
male_df = (pd.DataFrame(df[df['sex'] == 'MALE'][['species', 'sex']].groupby('species')['sex'].count()).sort_values('sex', ascending=False).reset_index().rename(columns={'Sex': 'Male'}))

male_df
# Out:
#      species  sex
# 0     Adelie   73
# 1     Gentoo   61
# 2  Chinstrap   34

# %%
species = ("Adelie", "Chinstrap", "Gentoo")
sex = {
    'Female': (73, 58, 34),
    'Male': (73, 61, 34)
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in sex.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=2)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Counts')
ax.set_title('Number of each gender per species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=2)
ax.set_ylim(0, 100)

plt.show()

# %% [markdown]
# ## Histogram 1
# ---

# %% [markdown]
# Below I present a histogram of the frequency of bill length for the three penguin species.

# %%
plt.figure(figsize = (10, 7)) 
x = df.bill_length_mm 

plt.hist(x, bins = 20, color = "orange", edgecolor = "black") 
plt.title("Bill Length in mm") 
plt.xlabel("Bill_Length_mm") 
plt.ylabel("Count") 

plt.show()

# %% [markdown]
# ## Histogram 2

# %%
import seaborn as sns

# %%
sns.FacetGrid(df, hue="species", height=7).map(sns.histplot, "bill_length_mm").add_legend()
plt.title("Bill Length in mm")  
plt.show()
# Out:
# c:\Users\sndrd\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# The first histogram shows the range for the bill length across the three different penguin species. The data indicates at least two different means for bill length as the data is not in a perfect normal distribution. This is most likely due to different species having a different mean for bill length which may be larger or smaller depending on the species of penguin. When we import seaborn and remake the histogram, it is clear to see that the mean bill length varies from speecies to species with the Chinstrap species having the largest mean at approx 50mm. Adelie has the smallest mean bill length at approx 37.5mm. The second histogram shows the three different distributions corresponding to each species.

# %% [markdown]
# # Analysis
# ---

# %% [markdown]
# In this section, I will analyse the correlation between bill length and body mass of the three species of penguin.

# %% [markdown]
# ## Violin Plot

# %%
import seaborn as sns

# %%
# Make a boxplot for bill length and body mass distribution for each species
g = sns.boxplot(y='species', x='bill_length_mm', data=df)
plt.title('Boxplot of bill length')
plt.show()
g = sns.boxplot(y='species', x='body_mass_g', data=df)
plt.title('Boxplot of body mass')
plt.show()

# %% [markdown]
# ## Scatter Plots

# %%
# scatterplot using seaborn


sns.scatterplot(x='bill_length_mm', y='body_mass_g', 
				hue='species', data=df, ) 

# Placing Legend outside the Figure 
plt.legend(bbox_to_anchor=(1, 1), loc=2) 

plt.title('Correlation between body mass and bill length')

plt.show()

# %%
#plt.figure(figsize=(8,6))
# penguin_corr = df.corr('bill_length_mm', 'body_mass_g')
#df = df[df.columns]
penguin_corr = df.corr(method = 'pearson')
#bool_upper_matrix = np.tril(np.ones(penguin_corr.shape)).astype(bool)
#corr = penguin_corr.where(bool_upper_matrix)
display(penguin_corr)
#sns.heatmap(penguin_corr, annot=True)
sns.heatmap(penguin_corr,
            xticklabels=penguin_corr.columns.values,
            yticklabels=penguin_corr.columns.values)
sns.plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 4
#       1 #plt.figure(figsize=(8,6))
#       2 # penguin_corr = df.corr('bill_length_mm', 'body_mass_g')
#       3 #df = df[df.columns]
# ----> 4 penguin_corr = df.corr(method = 'pearson')
#       5 #bool_upper_matrix = np.tril(np.ones(penguin_corr.shape)).astype(bool)
#       6 #corr = penguin_corr.where(bool_upper_matrix)
#       7 display(penguin_corr)
#
# File c:\Users\sndrd\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\sndrd\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\sndrd\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\sndrd\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Adelie'

# %% [markdown]
# ## References
# ---

# %% [markdown]
# 1. https://www.jmp.com/en_nl/statistics-knowledge-portal/exploratory-data-analysis/bar-chart.html.
# 2. https://www.jmp.com/en_nl/statistics-knowledge-portal/exploratory-data-analysis/histogram.html.
# 3. https://www.atlassian.com/data/charts/what-is-a-scatter-plot.
# 4. https://365datascience.com/tutorials/statistics-tutorials/distribution-in-statistics/.
# 5. https://www.analytixlabs.co.in/blog/types-of-distribution/.
# 6. Kristen B. Gorman, Tony D. Williams, William R. Fraser. "Ecological Sexual Dimorphism and Environmental Variability within a Community of Antarctic Penguins (Genus Pygoscelis)." PLoS ONE  (2014). https://doi.org/10.1371/journal.pone.0090081.

# %% [markdown]
# # End
